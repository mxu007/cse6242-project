# %%
import numpy as np
import pandas as pd
xl = pd.ExcelFile("/gtd_regression.xlsx")
df = xl.parse("Data")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-1eb39a8dcaea> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 xl = pd.ExcelFile("/gtd_regression.xlsx")
#       4 df = xl.parse("Data")
#       5 df.head()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     230     def __init__(self, io, **kwds):
#     231
# --> 232         import xlrd  # throw an ImportError if we need to
#     233
#     234         ver = tuple(map(int, xlrd.__VERSION__.split(".")[:2]))
#
# ModuleNotFoundError: No module named 'xlrd'

# %%
df_rg = df.copy()
df_rg['suicide'] = df.suicide.astype('category')
df_rg['attack_type'] = df.attack_type.astype('category')
df_rg['target_type'] = df.target_type.astype('category')
df_rg['nationality'] = df.nationality.astype('category')
df_rg['weapon_type'] = df.weapon_type.astype('category')
df_rg['casualty'] = df['nkill'] + df['nwound']
del df_rg['nkill']
del df_rg['nwound']
df_rg
# Out:
#         year                           country   latitude   longitude suicide  \
# 0       1970                Dominican Republic  18.456792  -69.951164       0
# 1       1970                            Mexico  19.432608  -99.133207       0
# 2       1970                       Philippines  15.478598  120.599741       0
# 3       1970                            Greece  37.983773   23.728157       0
# 4       1970                             Japan  33.580412  130.396361       0
# 5       1970                     United States  37.005105  -89.176269       0
# 6       1970                           Uruguay -34.891151  -56.187214       0
# 7       1970                     United States  37.805065 -122.273024       0
# 8       1970                     United States  43.076592  -89.412488       0
# 9       1970                     United States  43.072950  -89.386694       0
# 10      1970                     United States  43.468500  -89.744299       0
# 11      1970                     United States  39.740010 -104.992259       0
# 12      1970                             Italy  41.890520   12.494249       0
# 13      1970                     United States  42.331685  -83.047924       0
# 14      1970                     United States  18.399712  -66.049987       0
# 15      1970                East Germany (GDR)  52.516667   13.400000       0
# 16      1970                          Ethiopia        NaN         NaN       0
# 17      1970                     United States  40.610069  -73.947971       0
# 18      1970                     United States  18.379998  -65.830948       0
# 19      1970                     United States  47.603560 -122.329439       0
# 20      1970                     United States  40.116748  -88.239270       0
# 21      1970                           Uruguay -34.891151  -56.187214       0
# 22      1970                     United States  47.610594 -122.317228       0
# 23      1970                     United States  47.655335 -122.303520       0
# 24      1970                     United States  40.728075  -74.077825       0
# 25      1970                         Guatemala  14.624422  -90.532880       0
# 26      1970                       Philippines  14.677301  121.044348       0
# 27      1970                         Venezuela  10.502961  -66.917253       0
# 28      1970                     United States  42.470310  -96.413949       0
# 29      1970                     United States  33.606510  -88.650419       0
# ...      ...                               ...        ...         ...     ...
# 170320  2016                       Philippines   6.957127  124.474408       0
# 170321  2016                        Bangladesh  25.564362   89.519090       0
# 170322  2016                          Pakistan  30.661181   73.108576       0
# 170323  2016                      Saudi Arabia  16.889359   42.570567       0
# 170324  2016                       Afghanistan  34.533342   69.078022       0
# 170325  2016                           Burundi  -3.253245   29.430266       0
# 170326  2016                          Pakistan  34.014975   71.580490       0
# 170327  2016                             India  24.806454   93.920810       0
# 170328  2016                       Afghanistan  32.372459   62.120092       0
# 170329  2016                       Afghanistan  34.221242   69.078024       0
# 170330  2016                           Nigeria  11.831098   13.150967       1
# 170331  2016                              Iraq  34.345164   44.467121       0
# 170332  2016                              Iraq  33.381146   44.344940       1
# 170333  2016                              Iraq  33.332813   44.401060       1
# 170334  2016                              Iraq  33.332813   44.401060       1
# 170335  2016                              Iraq  33.305081   44.488947       0
# 170336  2016                              Iraq  33.370243   44.278691       0
# 170337  2016                              Iraq  36.352632   43.190460       1
# 170338  2016                          Pakistan  33.803879   72.025434       0
# 170339  2016                       Afghanistan  36.662402   65.748508       0
# 170340  2016                       Afghanistan  36.667981   65.751084       0
# 170341  2016                       Afghanistan  36.666222   65.754795       0
# 170342  2016                       Afghanistan  36.659695   65.752408       0
# 170343  2016                       Afghanistan  37.007020   66.026738       0
# 170344  2016                       Afghanistan  31.583664   64.368699       0
# 170345  2016                             Niger  13.883032   13.177504       0
# 170346  2016                       Philippines   7.027067  124.386552       0
# 170347  2016  Democratic Republic of the Congo   4.308611   25.091389       0
# 170348  2016                            Mexico  26.819644 -107.069898       0
# 170349  2016                             Sudan  12.961401   24.044116       0
#
#                            attack_type                     target_type  \
# 0                        Assassination     Private Citizens & Property
# 1          Hostage Taking (Kidnapping)         Government (Diplomatic)
# 2                        Assassination             Journalists & Media
# 3                    Bombing/Explosion         Government (Diplomatic)
# 4       Facility/Infrastructure Attack         Government (Diplomatic)
# 5                        Armed Assault                          Police
# 6                        Assassination                          Police
# 7                    Bombing/Explosion                       Utilities
# 8       Facility/Infrastructure Attack                        Military
# 9       Facility/Infrastructure Attack            Government (General)
# 10                   Bombing/Explosion                        Military
# 11      Facility/Infrastructure Attack                        Military
# 12                           Hijacking             Airports & Aircraft
# 13      Facility/Infrastructure Attack            Government (General)
# 14      Facility/Infrastructure Attack                        Business
# 15                   Bombing/Explosion            Government (General)
# 16                             Unknown                        Military
# 17                   Bombing/Explosion         Educational Institution
# 18                   Bombing/Explosion                        Business
# 19      Facility/Infrastructure Attack                        Business
# 20      Facility/Infrastructure Attack                          Police
# 21                       Armed Assault         Educational Institution
# 22                   Bombing/Explosion         Educational Institution
# 23                   Bombing/Explosion                        Military
# 24      Facility/Infrastructure Attack         Violent Political Party
# 25                       Assassination         Government (Diplomatic)
# 26                   Bombing/Explosion         Government (Diplomatic)
# 27         Hostage Taking (Kidnapping)                        Business
# 28                   Bombing/Explosion     Private Citizens & Property
# 29      Facility/Infrastructure Attack     Private Citizens & Property
# ...                                ...                             ...
# 170320                   Armed Assault                        Military
# 170321                   Assassination            Government (General)
# 170322                   Armed Assault                          Police
# 170323                   Armed Assault                        Military
# 170324               Bombing/Explosion     Private Citizens & Property
# 170325               Bombing/Explosion  Religious Figures/Institutions
# 170326                   Assassination     Private Citizens & Property
# 170327               Bombing/Explosion                        Business
# 170328                   Armed Assault                          Police
# 170329     Hostage Taking (Kidnapping)                        Military
# 170330               Bombing/Explosion     Private Citizens & Property
# 170334                              Iraq  Explosives/Bombs/Dynamite      36.0
# 170335                              Iraq  Explosives/Bombs/Dynamite       4.0
# 170336                              Iraq  Explosives/Bombs/Dynamite       8.0
# 170337                              Iraq  Explosives/Bombs/Dynamite       NaN
# 170338                          Pakistan                   Firearms       2.0
# 170339                       Afghanistan                    Unknown       2.0
# 170340                       Afghanistan                    Unknown       2.0
# 170341                       Afghanistan                    Unknown       2.0
# 170342                       Afghanistan                    Unknown       1.0
# 170343                       Afghanistan  Explosives/Bombs/Dynamite       7.0
# 170344                       Afghanistan  Explosives/Bombs/Dynamite       7.0
# 170345                             Niger                    Unknown      22.0
# 170346                       Philippines  Explosives/Bombs/Dynamite       0.0
# 170347  Democratic Republic of the Congo                    Unknown       NaN
# 170348                            Mexico                   Firearms       0.0
# 170349                             Sudan                   Firearms       0.0
#
# [170350 rows x 10 columns]

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import preprocessing
import seaborn as sns
# %matplotlib inline

## Regression example: Number of kills+wounded vs. avg_GDP of Country

def regression(df, country, year, predictor):

    df_c = df[df['country'] == country]
    df_cy = df_c[(df_c.year >= year[0]) & (df_c.year <= year[1])]
    X = df_cy[predictor]
    y = df_cy['casualty']
    Xy = pd.concat([X,y], axis = 1).dropna(how = 'any')

    # Note the difference in argument order
    model = smf.ols('casualty ~ {}'.format(predictor), data = Xy).fit()

    # Print out the statistics
    print ('The regression coefficients for the intercept and the selected predictor are \n {} \n and the p-values are \n {}.'.format(model.params, model.pvalues))
    
    # Create barplot
    #return sns.barplot(x = model.params.index, y = model.params)
    
regression(df_rg, 'United States', [2005, 2010], 'attack_type')
# Out:
# /Users/Wonhee/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# The regression coefficients for the intercept and the selected predictor are
#  Intercept                                             8.333333e+00
# attack_type[T.Assassination]                          4.965122e-15
# attack_type[T.Bombing/Explosion]                     -8.233333e+00
# attack_type[T.Facility/Infrastructure Attack]        -7.856061e+00
# attack_type[T.Hijacking]                              0.000000e+00
# attack_type[T.Hostage Taking (Barricade Incident)]   -7.333333e+00
# attack_type[T.Hostage Taking (Kidnapping)]            0.000000e+00
# attack_type[T.Unarmed Assault]                       -6.333333e+00
# attack_type[T.Unknown]                                0.000000e+00
# dtype: float64
#  and the p-values are
#  Intercept                                             0.000005
# attack_type[T.Assassination]                          0.252782
# attack_type[T.Bombing/Explosion]                      0.000134
# attack_type[T.Facility/Infrastructure Attack]         0.000069
# attack_type[T.Hijacking]                                   NaN
# attack_type[T.Hostage Taking (Barricade Incident)]    0.175779
# attack_type[T.Hostage Taking (Kidnapping)]                 NaN
# attack_type[T.Unarmed Assault]                        0.028709
# attack_type[T.Unknown]                                     NaN
# dtype: float64.
# /Users/Wonhee/anaconda/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /Users/Wonhee/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/Wonhee/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/Wonhee/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
regression(df_rg, 'United States', [2005, 2010], 'suicide')
# Out:
# The regression coefficients for the intercept and the selected predictor are
#  Intercept       1.171053
# suicide[T.1]    5.495614
# dtype: float64
#  and the p-values are
#  Intercept       0.067609
# suicide[T.1]    0.094071
# dtype: float64.
